# %%
using Seismic
# Out:
# INFO: Loading help data...

# %%
param = ["adj"=>"y",
    "vel"=>"../prep/vp", "wav"=>"../prep/wav",
    "angx"=>"../prep/angx","angy"=>"../prep/angy",
    "pade_flag"=>"y",
    "sz"=>10, "gz"=>550,
    "fmin"=>1., "fmax"=>50.,
    "padt"=>2, "padx"=>1,
    "nangx"=>71, "oangx"=>-70, "dangx"=>2,
    "nangy"=>1, "oangy"=>0, "dangy"=>2,
    "nhx"=>827, "ohx"=>-3304, "dhx"=>8,
    "nhy"=>1, "ohy"=>0, "dhy"=>8,
    "omp"=>8,"verbose"=>"y"];
param["sx"] = [5100.0:100.0:5100.0];
param["sy"] = [5100.0:100.0:5100.0]*0;
ShotProfileWEM("../prep/uz_1shot","mpp",param);
# Out:
# argv[1]=adj=y
# argv[2]=d=../prep/uz_1shot_shot_5100_0
# argv[3]=m=mpp_shot_5100_0
# argv[4]=vel=../prep/vp
# argv[5]=wav=../prep/wav
# argv[6]=sx=5100.0
# argv[7]=sy=0.0
# argv[8]=sz=10
# argv[9]=gz=550
# argv[10]=ohx=-3304
# argv[11]=dhx=8
# argv[12]=nhx=827
# argv[13]=ohy=0
# argv[14]=dhy=8
# argv[15]=nhy=1
# argv[16]=fmin=1.0
# argv[17]=fmax=50.0
# argv[18]=padt=2
# argv[19]=padx=1
# argv[20]=pade_flag=y
# argv[21]=verbose=y
# [ 99.75% complete]

# %%
#argv = [];
argv = ["0", "adj=y", 
    "d=../prep/uz_1shot", "m=mpp_shot_5100_0",
    "vel=../prep/vp", "wav=../prep/wav", 
    "sx=5100.0", "sy=0.0", "sz=10", "gz=550", 
    "ohx=-3304", "dhx=8", "nhx=827","ohy=0", "dhy=8", "nhy=1",
    "fmin=1.0", "fmax=50.0", "padt=2","padx=1", "pade_flag=y", "verbose=y"];
a = ccall((:main, "/Users/astanton/Seismic_SAIG/src/API/c/shotwem.so"), Int32, (Int32, Ptr{Ptr{Uint8}}), length(argv), argv)
# Out:
# This program was called with "adj=y".
# argv[1] = d=../prep/uz_1shot
# argv[2] = m=mpp_shot_5100_0
# argv[3] = vel=../prep/vp
# argv[4] = wav=../prep/wav
# argv[5] = sx=5100.0
# argv[6] = sy=0.0
# argv[7] = sz=10
# argv[8] = gz=550
# argv[9] = ohx=-3304
# argv[10] = dhx=8
# argv[11] = nhx=827
# argv[12] = ohy=0
# argv[13] = dhy=8
# argv[14] = nhy=1
# argv[15] = fmin=1.0
# argv[16] = fmax=50.0
# argv[17] = padt=2
# argv[18] = padx=1
# argv[19] = pade_flag=y
# argv[20] = verbose=y
# 0

# %%
SeisWindow("mpp","mpp_mute",["ang"],[-20],[20])
SeisStack("mpp_mute","mpp_stack",["key"=>["imx","imy"]]);
mpp_stack,h = SeisRead("mpp_stack");
plotpar = ["style"=>"color","vmin"=>-2e-3,"vmax"=>2e-3,"aspect"=>"1.5","xlabel"=>"X","xunits"=>"(m)","ox"=>0.,"dx"=>8.,"ylabel"=>"Depth","yunits"=>"(m)","oy"=>0.,"dy"=>4,"cmap"=>"Greys"];
SeisPlot(mpp_stack,["vmin"=>-1e3,"vmax"=>1e3,"cmap"=>"PuOr"]);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1231de3d0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x1025c6fd0>)

# %%
SeisWindow("mpp","mpp_gather",["imx"],[500],[500])
mpp_gather,h = SeisRead("mpp_gather");
Seismic.subplot(131)
SeisPlot(mpp_gather,["vmin"=>-1e4,"vmax"=>1e4,"cmap"=>"PuOr"]);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x102f29c90>)
